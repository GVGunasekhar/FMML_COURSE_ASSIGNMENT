# %% [markdown]
# <a href="https://colab.research.google.com/github/GVGunasekhar/FMML_COURSE_ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-05 04:36:19--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   178MB/s    in 0.4s
#
# 2023-05-05 04:36:24 (178 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 19555   0906.4332v2  There are several well-known justifications fo...    cs
# 7628   1802.05431v1  We provide convergence guarantees in Wasserste...  stat
# 22121   1412.8765v2  We consider the problem of uncertainty assessm...  stat
# 28429  1706.06266v2  Multi-frame image super-resolution (MISR) aims...    cs
# 8912   1703.08098v3  Knowledge bases (KBs) of real-world facts abou...    cs
# ...             ...                                                ...   ...
# 3184    1206.4676v1  Clustering analysis by nonnegative low-rank ap...    cs
# 13872  1601.04187v1  In recent years the field of neuromorphic low-...    cs
# 2814   1802.00541v1  Deep neural networks are complex and opaque. A...    cs
# 3493   1709.01779v2  Over the last few years, deep learning has rev...  stat
# 26729  1611.07559v1  This letter presents a method of synthetic ape...    cs
#
#                                                    title  year  \
# 19555                     Updating Sets of Probabilities  2009
# 7628   On the Theory of Variance Reduction for Stocha...  2018
# 22121  A General Theory of Hypothesis Tests and Confi...  2014
# 28429  Multi-frame image super-resolution with fast u...  2017
# 8912   An overview of embedding models of entities an...  2017
# ...                                                  ...   ...
# 3184   Clustering by Low-Rank Doubly Stochastic Matri...  2012
# 13872  Conversion of Artificial Recurrent Neural Netw...  2016
# 2814   Causal Learning and Explanation of Deep Neural...  2018
# 3493                           Deep learning from crowds  2017
# 26729  Sar image despeckling based on nonlocal simila...  2016
#
#                                                 keywords
# 19555  [justifications, conditioning, appropriate, pr...
# 7628   [convergence, guarantees, wasserstein, reducti...
# 22121  [uncertainty, assessment, dimensional, compone...
# 28429  [resolution, information, resolution, resoluti...
# 8912   [knowledge, relationships, resources, processi...
# ...                                                  ...
# 3184   [clustering, nonnegative, approximations, rema...
# 13872  [neuromorphic, magnitude, significant, algorit...
# 2814   [application, important, predictions, explaini...
# 3493   [revolutionized, dramatically, improving, supe...
# 26729  [synthetic, despeckling, information, suppress...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 19555    [justifications, conditioning, appropriate, pr...
# 7628     [convergence, guarantees, wasserstein, reducti...
# 22121    [uncertainty, assessment, dimensional, compone...
# 28429    [resolution, information, resolution, resoluti...
# 8912     [knowledge, relationships, resources, processi...
#                                ...
# 13506    [optimization, heuristic, continuous, optimiza...
# 1563     [algorithm, improving, injecting, constraints,...
# 10586    [clustering, algorithm, chaudhuri, variations,...
# 34270    [mathematical, structure, mathematics, sylvest...
# 39052    [classification, developing, stimulation, cons...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8814 words.
# Out of those 4536 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5d115e2e-e129-4bb8-804f-4b4da4866702" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d115e2e-e129-4bb8-804f-4b4da4866702")) {                    Plotly.newPlot(                        "5d115e2e-e129-4bb8-804f-4b4da4866702",                        [{"x":["uncertainty","probability","preferred","different","realistic","appropriate","conditioning","axiomatization","literature","axiomatic","procedure","sufficient","individually","justified","observation","significant","considering","condition","probabilities","considerably","justifications","lipschitz","posterior","underdamped","optimization","wasserstein","theoretical","reduction","assumptions","technique","convergence","distribution","diffusion","stochastic","combining","guarantees","synthetic","experiments","decorrelated","specifically","inference","misspecification","parameters","dimensional","applicable","confidence","individual","construct","applications","introducing","generalized","exponentially","efficient","alternatives","furthermore","characterize","likelihood","generalize","distributions","functions","estimators","perspective","components","framework","establish","assessment","inferential","hypothesis","asymptotic","developed","conducted","penalized","statistic","numerical","information","attaching","demonstrate","shuffling","locations","effectiveness","upscaling","operation","interpolation","significance","resolution","respectively","efficiency","alleviate","projection","introduce","computational","artifacts","bilateral","additional","variation","inevitable","posedness","especially","performance","transitions","reconstruction","utilizing","outperforms","experimental","extensive","extensively","approaches","complexity","completion","summarizing","processing","relationship","typically","incomplete","relationships","benchmark","knowledge","prediction","resources","embedding","privately","particular","algorithm","practical","approximately","consistent","conceptual","searching","constraint","existence","sensitive","necessity","differential","minimizes","conditions","stability","sufficiency","learnability","empirical","universally","algorithms","principle","transition","learnable","asymptotically","intricate","substantially","decreasing","organized","hierarchy","abstraction","representations","hierarchical","evaluated","traditional","classifiers","introduced","categories","classification","convolutional","distinguish","traditionally","predictions","corresponding","sequential","concatenated","structure","difficult","exclusively","extensions","successively","assumption","mitigated","potential","correlated","integration","iteration","comprises","mitigation","technology","effective","convergent","industries","iterations","production","representative","connected","essential","implementation","maintenance","consumption","character","modifications","vocabulary","architectures","perplexity","extremely","proposing","timescales","recognition"],"y":[77,182,21,767,66,74,11,4,117,7,146,82,12,5,56,255,75,48,62,25,3,7,41,0,328,5,152,105,62,256,113,221,16,141,110,69,136,583,1,183,210,0,248,176,54,43,135,85,421,47,77,21,427,23,165,52,74,49,118,230,18,61,109,548,63,49,1,49,19,176,81,3,8,82,687,3,570,6,40,200,4,44,20,13,120,98,169,25,51,363,287,28,7,131,60,8,3,117,905,13,104,47,258,380,184,43,421,253,41,6,298,71,108,33,71,225,366,231,75,105,0,271,818,127,26,99,20,34,83,36,59,6,31,10,131,53,1,6,136,3,611,53,26,8,14,2,38,12,15,35,30,243,114,144,197,112,139,62,517,411,34,26,96,153,61,9,343,143,5,39,7,70,4,151,35,55,45,19,7,55,226,7,7,26,26,37,77,71,132,9,26,45,13,30,130,12,47,17,3,376],"type":"bar"},{"x":["uncertainty","probability","preferred","different","realistic","appropriate","conditioning","axi ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4536,), (4536, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8016666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style='background-color:rgba(0, 255, 0, 0.34749034749034746);'>Representation</span> <span style=''>for</span> <span style=''>Natural</span> <span style=''>Language</span> <span style='background-color:rgba(0, 255, 0, 0.42583732057416274);'>Processing</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Kernelized</span> <span style=''>Hashcodes</span> <br/><br/><span style=''>Kernel</span> <span style=''>methods</span> <span style=''>have</span> <span style=''>been</span> <span style=''>used</span> <span style=''>widely</span> <span style=''>in</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style=''>tasks</span> <span style=''>but</span> <span style=''>have</span> <span style=''>had</span> <span style=''>limited</span> <span style=''>success</span> <span style=''>in</span> <span style=''>Natural</span> <span style=''>Language</span> <span style='background-color:rgba(0, 255, 0, 0.42583732057416274);'>Processing</span> <span style=''>(NLP)</span> <span style=''>due</span> <span style=''>to</span> <span style=''>high</span> <span style=''>cost</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computing</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarities</span> <span style=''>between</span> <span style=''>discrete</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>A</span> <span style=''>recently</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Kernelized</span> <span style=''>Locality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Sensitive</span> <span style=''>Hashing</span> <span style=''>(KLSH)</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significantly</span> <span style=''>reduce</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>cost</span> <span style=''>but</span> <span style=''>is</span> <span style=''>only</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applicable</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>operating</span> <span style=''>on</span> <span style=''>kNN</span> <span style=''>graphs</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>use</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>subspaces</span> <span style=''>of</span> <span style=''>KLSH</span> <span style=''>codes</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructing</span> <span style=''>explicit</span> <span style='background-color:rgba(0, 255, 0, 0.34749034749034746);'>representation</span> <span style=''>of</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>suitable</span> <span style=''>for</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>methods</span> <span style=''>Further</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizing</span> <span style=''>a</span> <span style=''>KLSH</span> <span style=''>model</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Nominal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Association</span> <span style=''>Vector</span> <span style=''>and</span> <span style=''>Matrix</span> <br/><br/><span style=''>When</span> <span style=''>response</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>are</span> <span style=''>nominal</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>populations</span> <span style=''>are</span> <span style=''>cross</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classified</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>multiple</span> <span style=''>polytomies</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>questions</span> <span style=''>often</span> <span style=''>arise</span> <span style=''>about</span> <span style=''>the</span> <span style=''>degree</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>association</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>responses</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explanatory</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>When</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>populations</span> <span style=''>are</span> <span style=''>known</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>nominal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>association</span> <span style=''>vector</span> <span style=''>and</span> <span style=''>matrix</span> <span style=''>to</span> <span style=''>evaluate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependence</span> <span style=''>of</span> <span style=''>a</span> <span style=''>response</span> <span style=''>variable</span> <span style=''>with</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explanatory</span> <span style=''>variable</span> <span style=''>These</span> <span style=''>measures</span> <span style=''>provide</span> <span style=''>detailed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluations</span> <span style=''>of</span> <span style=''>nominal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associations</span> <span style=''>at</span> <span style=''>both</span> <span style=''>local</span> <span style=''>and</span> <span style=''>global</span> <span style=''>levels</span> <span style=''>We</span> <span style=''>also</span> <span style=''>define</span> <span style=''>a</span> <span style=''>general</span> <span style=''>class</span> <span style=''>of</span> <span style=''>global</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>association</span> <span style=''>measures</span> <span style=''>which</span> <span style=''>embraces</span> <span style=''>the</span> <span style=''>well</span> <span style=''>known</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>association</span> <span style=''>measure</span> <span style=''>by</span> <span style=''>Goodman</span> <span style=''>Kruskal</span> <span style=''>(1954)</span> <span style=''>The</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>association</span> <span style=''>matrix</span> <span style=''>also</span> <span style=''>gives</span> <span style=''>rise</span> <span style=''>to</span> <span style=''>the</span> <span style=''>expected</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>confusion</span> <span style=''>matrix</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>The</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>From</span> <span style=''>Bandits</span> <span style=''>to</span> <span style=''>Experts</span> <span style=''>On</span> <span style=''>the</span> <span style=''>Value</span> <span style=''>of</span> <span style=''>Side</span> <span style='background-color:rgba(255, 0, 0, 0.32188841201716734);'>Observations</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversarial</span> <span style=''>online</span> <span style=''>learning</span> <span style=''>setting</span> <span style=''>where</span> <span style=''>a</span> <span style=''>decision</span> <span style=''>maker</span> <span style=''>can</span> <span style=''>choose</span> <span style=''>an</span> <span style=''>action</span> <span style=''>in</span> <span style=''>every</span> <span style=''>stage</span> <span style=''>of</span> <span style=''>the</span> <span style=''>game</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.37931034482758624);'>observing</span> <span style=''>the</span> <span style=''>reward</span> <span style=''>of</span> <span style=''>the</span> <span style=''>chosen</span> <span style=''>action</span> <span style=''>the</span> <span style=''>decision</span> <span style=''>maker</span> <span style=''>gets</span> <span style=''>side</span> <span style='background-color:rgba(255, 0, 0, 0.32188841201716734);'>observations</span> <span style=''>on</span> <span style=''>the</span> <span style=''>reward</span> <span style=''>he</span> <span style=''>would</span> <span style=''>have</span> <span style=''>obtained</span> <span style=''>had</span> <span style=''>he</span> <span style=''>chosen</span> <span style=''>some</span> <span style=''>of</span> <span style=''>the</span> <span style=''>other</span> <span style=''>actions</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>is</span> <span style=''>encoded</span> <span style=''>as</span> <span style=''>a</span> <span style=''>graph</span> <span style=''>where</span> <span style=''>node</span> <span style=''>i</span> <span style=''>is</span> <span style=''>linked</span> <span style=''>to</span> <span style=''>node</span> <span style=''>j</span> <span style=''>if</span> <span style=''>sampling</span> <span style=''>i</span> <span style=''>provides</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>on</span> <span style=''>the</span> <span style=''>reward</span> <span style=''>of</span> <span style=''>j</span> <span style=''>This</span> <span style=''>setting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>naturally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpolates</span> <span style=''>between</span> <span style=''>the</span> <span style=''>well</span> <span style=''>known</span> <span style=''>experts</span> <span style=''>setting</span> <span style=''>where</span> <span style=''>the</span> <span style=''>decision</span> <span style=''>maker</span> <span style=''>can</span> <span style=''>view</span> <span style=''>all</span> <span style=''>rewards</span> <span style=''>and</span> <span style=''>the</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandits</span> <span style=''>setting</span> <span style=''>where</span> <span style=''>the</span> <span style=''>decision</span> <span style=''>maker</span> <span style=''>can</span> <span style=''>only</span> <span style=''>view</span> <span style=''>the</span> <span style=''>reward</span> <span style=''>of</span> <span style=''>the</span> <span style=''>chosen</span> <span style=''>action</span> <span style=''>We</span> <span style=''>develop</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coherence</span> <span style=''>and</span> <span style=''>proper</span> <span style=''>scoring</span> <span style=''>rules</span> <br/><br/><span style=''>We</span> <span style=''>provide</span> <span style=''>self</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contained</span> <span style=''>proof</span> <span style=''>of</span> <span style=''>a</span> <span style=''>theorem</span> <span style=''>relating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coherence</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>forecasts</span> <span style=''>to</span> <span style=''>their</span> <span style=''>non</span> <span style=''>domination</span> <span style=''>by</span> <span style=''>rival</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>forecasts</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>any</span> <span style=''>proper</span> <span style=''>scoring</span> <span style=''>rule</span> <span style=''>The</span> <span style=''>theorem</span> <span style=''>appears</span> <span style=''>to</span> <span style=''>be</span> <span style=''>new</span> <span style=''>but</span> <span style=''>is</span> <span style=''>closely</span> <span style=''>related</span> <span style=''>to</span> <span style=''>results</span> <span style=''>achieved</span> <span style=''>by</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigators</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.10381733856582233)
# 	experimental (0.13556903317873706)
# 	knowledge (0.1305743845879415)
# 	information (0.24509454156261148)
# 	architecture (0.08990367463432038)
# 	segmentation (0.07491972886193364)
# 	detection (0.12450945415626115)
# 	different (0.2736353906528719)
# 	recognition (0.13414199072422406)
# 	convolutional (0.14662861220121298)
#
# Some Statistics words are:
# 	convergence (0.12168252378567852)
# 	estimation (0.17175763645468203)
# 	variables (0.1387080620931397)
# 	algorithm (0.3900851276915373)
# 	distribution (0.17876815222834253)
# 	theoretical (0.15473209814722083)
# 	statistical (0.15823735603405106)
# 	inference (0.2028042063094642)
# 	dimensional (0.19679519278918378)
# 	regression (0.1887831747621432)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d49b1529-de06-438e-97c2-39440b53be47" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d49b1529-de06-438e-97c2-39440b53be47")) {                    Plotly.newPlot(                        "d49b1529-de06-438e-97c2-39440b53be47",                        [{"x":["uncertainty","probability","preferred","different","realistic","appropriate","conditioning","axiomatization","literature","axiomatic","procedure","sufficient","individually","justified","observation","significant","considering","condition","probabilities","considerably","justifications","lipschitz","posterior","underdamped","optimization","wasserstein","theoretical","reduction","assumptions","technique","convergence","distribution","diffusion","stochastic","combining","guarantees","synthetic","experiments","decorrelated","specifically","inference","misspecification","parameters","dimensional","applicable","confidence","individual","construct","applications","introducing","generalized","exponentially","efficient","alternatives","furthermore","characterize","likelihood","generalize","distributions","functions","estimators","perspective","components","framework","establish","assessment","inferential","hypothesis","asymptotic","developed","conducted","penalized","statistic","numerical","information","attaching","demonstrate","shuffling","locations","effectiveness","upscaling","operation","interpolation","significance","resolution","respectively","efficiency","alleviate","projection","introduce","computational","artifacts","bilateral","additional","variation","inevitable","posedness","especially","performance","transitions","reconstruction","utilizing","outperforms","experimental","extensive","extensively","approaches","complexity","completion","summarizing","processing","relationship","typically","incomplete","relationships","benchmark","knowledge","prediction","resources","embedding","privately","particular","algorithm","practical","approximately","consistent","conceptual","searching","constraint","existence","sensitive","necessity","differential","minimizes","conditions","stability","sufficiency","learnability","empirical","universally","algorithms","principle","transition","learnable","asymptotically","intricate","substantially","decreasing","organized","hierarchy","abstraction","representations","hierarchical","evaluated","traditional","classifiers","introduced","categories","classification","convolutional","distinguish","traditionally","predictions","corresponding","sequential","concatenated","structure","difficult","exclusively","extensions","successively","assumption","mitigated","potential","correlated","integration","iteration","comprises","mitigation","technology","effective","convergent","industries","iterations","production","representative","connected","essential","implementation","maintenance","consumption","character","modifications","vocabulary","architectures","perplexity","extremely","proposing","timescales","recognition","accuracies","recurrent","structures","replacing","generally","expressed","linguistic","complicated","transform","representation","calculated","translation","calculation","threshold","relations","definition","distributed","mathematical","similarity","performances","perceptron","simulates","satellite","alternative","incorporate","neighborhood","enhancement","characteristics","autoencoder","predictive","nonetheless","geographical","autoencoders","denoising","considered","detecting","phenomenon","plagiarism","discarding","advantage","multimedia","retrieval","flowchart","according","therefore","detection","important","automatic","extraction","generating","modulation","dramatically","generated","communication","accomplish","challenging","mechanism","perfor ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	underdamped
# 	misspecification
# 	privately
# 	perturbative
# 	preconditioned
# 	magnetoencephalographic
# 	irreducible
# 	tibshirani
# 	complemented
# 	debiasing
# 	discretisation
# 	standardizing
# 	nonparanormal
# 	semiparametric
# 	parallelizes
# 	parallelize
# 	explanatory
# 	disaggregation
# 	unnatural
# 	bernstein
# Some words which never appear in Statistics papers:
# 	axiomatization
# 	justifications
# 	upscaling
# 	bilateral
# 	inevitable
# 	posedness
# 	mitigated
# 	plagiarism
# 	flowchart
# 	uncompressed
# 	orderless
# 	civilizations
# 	archaeological
# 	photographic
# 	renderings
# 	rectifier
# 	nondeterminism
# 	pedestrian
# 	interlocutors
# 	conversation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0706872197997915e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7608333333333334
